# %% [markdown]
# # Exercício 1 (Etapa 1): Examinando o Anaconda e familiarizando-se com o Python
#
# ## Passo 1: Examinando os pacotes instalados
#
# Digite `conda list` no terminal para ver todos os pacotes instalados no ambiente Anaconda.

# %%
# Equivalente ao "conda list" — lista todos os pacotes instalados no ambiente
# !C:\Users\mathe\miniconda3\Scripts\conda list
# Out:
# # packages in environment at C:\Users\mathe\miniconda3:
# #
# # Name                        Version          Build               Channel
# anaconda-anon-usage           0.7.5            pyhb46e38b_100
# anaconda-auth                 0.13.0           py313haa95532_0
# anaconda-cli-base             0.8.1            py313haa95532_0
# anaconda_powershell_prompt    1.1.0            haa95532_1
# anaconda_prompt               1.1.0            haa95532_1
# annotated-types               0.6.0            py313haa95532_1
# anyio                         4.10.0           py313haa95532_0
# archspec                      0.2.5            pyhd3eb1b0_0
# boltons                       25.0.0           py313haa95532_0
# brotlicffi                    1.2.0.0          py313h885b0b7_0
# bzip2                         1.0.8            h2bbff1b_6
# ca-certificates               2025.12.2        haa95532_0
# certifi                       2026.01.04       py313haa95532_0
# ...

# %% [markdown]
# ## Passo 2: Abrindo o interpretador Python
#
# Digite `python` no terminal para abrir o interpretador Python de linha de comando. Você verá informações sobre a versão do Python e o prompt `>>>`, que indica que pode começar a digitar código Python.
#
# No Jupyter, podemos verificar essas informações diretamente:

# %%
import sys

# Exibe as mesmas informações que aparecem ao digitar "python" no terminal
print(f"Python {sys.version}")
print(f"Type \"help\", \"copyright\", \"credits\" or \"license\" for more information.")
# Out:
# Python 3.12.11 (main, Jun  7 2025, 12:31:44)  [GCC 15.1.0 64 bit (AMD64)]
# Type "help", "copyright", "credits" or "license" for more information.

# %% [markdown]
# ## Passo 3: Criando um loop for no interpretador
#
# No terminal, digitamos o loop linha a linha após o prompt `>>>`:
#
# ```
# >>> for counter in range(5):
# ...     print(counter)
# ...
# ```
#
# No Jupyter, escrevemos o bloco completo diretamente na célula:

# %%
for counter in range(5):
    print(counter)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Passo 4: Criando um dicionário
#
# Crie um dicionário de frutas com as chaves `apples`, `oranges` e `bananas`:

# %%
example_dict = {'apples': 5, 'oranges': 8, 'bananas': 13}
example_dict
# Out:
# {'apples': 5, 'oranges': 8, 'bananas': 13}

# %% [markdown]
# ## Passo 5: Corvetendo um dicionário para lista
#
# Converta o dicionário em uma lista usando a função list()

# %%
dict_to_list = list(example_dict)
dict_to_list
# Out:
# ['apples', 'oranges', 'bananas']
